# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('./juliet_split.csv.gz')

# %%
data
# Out:
#         Unnamed: 0  testcase_ID  \
# 0                0        61940
# 1                1        61941
# 2                2        61942
# 3                3        61943
# 4                4        61944
# 5                5        61945
# 6                6        61946
# 7                7        61947
# 8                8        61948
# 9                9        61949
# 10              10        61950
# 11              11        61951
# 12              12        61952
# 13              13        61953
# 14              14        61954
# 15              15        61955
# 16              16        61956
# 17              17        61957
# 18              18        61958
# 19              19        61959
# 20              20        61959
# 21              21        61960
# 22              22        61961
# 23              23        61962
# 24              24        61963
# 25              25        61964
# 26              26        61965
# 27              27        61966
# ...

# %%
print(data.iloc[1].code)
# Out:
# /* TEMPLATE GENERATED TESTCASE FILE
# Filename: CWE114_Process_Control__w32_char_connect_socket_02.c
# Label Definition File: CWE114_Process_Control__w32.label.xml
# Template File: sources-sink-02.tmpl.c
# */
# /*
#  * @description
#  * CWE: 114 Process Control
#  * BadSource: connect_socket Read data using a connect socket (client side)
#  * GoodSource: Hard code the full pathname to the library
#  * Sink:
#  *    BadSink : Load a dynamic link library
#  * Flow Variant: 02 Control flow: if(1) and if(0)
#  *
#  * */
#
# #include "std_testcase.h"
#
# #include <wchar.h>
#
# #ifdef _WIN32
# #include <winsock2.h>
# #include <windows.h>
# #include <direct.h>
# #pragma comment(lib, "ws2_32") /* include ws2_32.lib when linking */
# #define CLOSE_SOCKET closesocket
# #else /* NOT _WIN32 */
# #include <sys/types.h>
# #include <sys/socket.h>
# #include <netinet/in.h>
# #include <arpa/inet.h>
# #include <unistd.h>
# #define INVALID_SOCKET -1
# #define SOCKET_ERROR -1
# ...

# %%
data = data.drop_duplicates().sort_values('testcase_ID').reset_index(drop=True)

# %%
data
# Out:
#         Unnamed: 0  testcase_ID  \
# 0           105182      -248722
# 1           105179      -248722
# 2           105181      -248722
# 3           105180      -248722
# 4           105175      -248721
# 5           105178      -248721
# 6           105177      -248721
# 7           105176      -248721
# 8           105172      -248720
# 9           105174      -248720
# 10          105173      -248720
# 11          105171      -248720
# 12          105167      -248719
# 13          105170      -248719
# 14          105169      -248719
# 15          105168      -248719
# 16          105165      -248718
# 17          105166      -248718
# 18          105163      -248717
# 19          105164      -248717
# 20          105161      -248716
# 21          105162      -248716
# 22          105160      -248715
# 23          105159      -248715
# 24          105157      -248714
# 25          105158      -248714
# 26          105155      -248713
# 27          105156      -248713
# ...

# %%
labels = data.copy()
del labels['Unnamed: 0']
labels.drop_duplicates(subset ='testcase_ID', keep = False, inplace = True)

# %%
labels
# Out:
#         testcase_ID                                           filename  \
# 52          -248703  000/248/703/CWE78_OS_Command_Injection__wchar_...
# 53          -248702  000/248/702/CWE78_OS_Command_Injection__wchar_...
# 54          -248701  000/248/701/CWE78_OS_Command_Injection__wchar_...
# 55          -248700  000/248/700/CWE78_OS_Command_Injection__wchar_...
# 56          -248699  000/248/699/CWE78_OS_Command_Injection__wchar_...
# 57          -248698  000/248/698/CWE78_OS_Command_Injection__wchar_...
# 58          -248697  000/248/697/CWE78_OS_Command_Injection__wchar_...
# 59          -248696  000/248/696/CWE78_OS_Command_Injection__wchar_...
# 60          -248695  000/248/695/CWE78_OS_Command_Injection__wchar_...
# 63          -248693  000/248/693/CWE78_OS_Command_Injection__wchar_...
# 64          -248692  000/248/692/CWE78_OS_Command_Injection__wchar_...
# 65          -248691  000/248/691/CWE78_OS_Command_Injection__wchar_...
# ...

# %%
labels.to_csv('./juliet_split_drop_duplicates.csv')

# %%
data3 = pd.read_csv('./juliet_split_drop_duplicates.csv')
data3
# Out:
#        Unnamed: 0  testcase_ID  \
# 0              52      -248703
# 1              53      -248702
# 2              54      -248701
# 3              55      -248700
# 4              56      -248699
# 5              57      -248698
# 6              58      -248697
# 7              59      -248696
# 8              60      -248695
# 9              63      -248693
# 10             64      -248692
# 11             65      -248691
# 12             66      -248690
# 13             67      -248689
# 14             68      -248688
# 15             69      -248687
# 16             70      -248686
# 17             71      -248685
# 18             72      -248684
# 19             73      -248683
# 20             74      -248682
# 21             75      -248681
# 22             76      -248680
# 23             77      -248679
# 24             78      -248678
# 25             79      -248677
# 26             80      -248676
# 27             81      -248675
# 28            134      -248655
# ...

# %%
import swifter
# Out:
# /usr/local/lib/python3.6/dist-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %%
data4 = pd.read_csv('./buffer_overflow_data.csv.gz')
data4
# Out:
#        Unnamed: 0  Unnamed: 0.1  testcase_ID  \
# 0             984           984        62516
# 1             985           985        62517
# 2             986           986        62518
# 3             987           987        62519
# 4             988           988        62520
# 5             989           989        62521
# 6             990           990        62522
# 7             991           991        62523
# 8             992           992        62524
# 9             993           993        62525
# 10            994           994        62526
# 11            995           995        62527
# 12            996           996        62528
# 13            997           997        62529
# 14            998           998        62530
# 15            999           999        62531
# 16           1000          1000        62532
# 17           1001          1001        62533
# 18           1002          1002        62534
# 19           1003          1003        62535
# ...

# %%
import torch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-eb42ca6e4af3> in <module>
# ----> 1 import torch
#
# ModuleNotFoundError: No module named 'torch'

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-7e0b528b9237> in <module>
# ----> 1 from train import *
#
# /project/train.py in <module>
#       1 import pandas as pd
#       2 import random
# ----> 3 import torch
#       4 import time
#       5 import numpy as np
#
# ModuleNotFoundError: No module named 'torch'

# %%
datasmall = pd.read_csv('./vdisc_train_buffer_over_data_small.csv.gz')

# %%
datasmall
# Out:
#        Unnamed: 0  testcase_ID  flaw_loc filename  \
# 0              80            0       NaN   test.c
# 1             112            1       NaN   test.c
# 2             148            2       NaN   test.c
# 3             155            3       NaN   test.c
# 4             235            4       NaN   test.c
# 5             358            5       NaN   test.c
# 6             521            6       NaN   test.c
# 7             548            7       NaN   test.c
# 8             776            8       NaN   test.c
# 9             784            9       NaN   test.c
# 10            788           10       NaN   test.c
# 11            861           11       NaN   test.c
# 12           1114           12       NaN   test.c
# 13           1150           13       NaN   test.c
# 14           1155           14       NaN   test.c
# 15           1372           15       NaN   test.c
# 16           1443           16       NaN   test.c
# 17           1454           17       NaN   test.c
# ...

# %%
datav = pd.read_csv('./vdisc_train.csv.gz')

# %%
datav
# Out:
#          Unnamed: 0             testcase_ID  flaw_loc  filename  \
# 0                 0        vdisc_testcase_0       NaN       NaN
# 1                 1        vdisc_testcase_1       NaN       NaN
# 2                 2        vdisc_testcase_2       NaN       NaN
# 3                 3        vdisc_testcase_3       NaN       NaN
# 4                 4        vdisc_testcase_4       NaN       NaN
# 5                 5        vdisc_testcase_5       NaN       NaN
# 6                 6        vdisc_testcase_6       NaN       NaN
# 7                 7        vdisc_testcase_7       NaN       NaN
# 8                 8        vdisc_testcase_8       NaN       NaN
# 9                 9        vdisc_testcase_9       NaN       NaN
# 10               10       vdisc_testcase_10       NaN       NaN
# 11               11       vdisc_testcase_11       NaN       NaN
# 12               12       vdisc_testcase_12       NaN       NaN
# 13               13       vdisc_testcase_13       NaN       NaN
# ...

# %%
datat = pd.read_csv('./vdisc_test.csv.gz')

# %%
datat
# Out:
#         Unnamed: 0            testcase_ID  flaw_loc  filename  \
# 0                0       vdisc_testcase_0       NaN       NaN
# 1                1       vdisc_testcase_1       NaN       NaN
# 2                2       vdisc_testcase_2       NaN       NaN
# 3                3       vdisc_testcase_3       NaN       NaN
# 4                4       vdisc_testcase_4       NaN       NaN
# 5                5       vdisc_testcase_5       NaN       NaN
# 6                6       vdisc_testcase_6       NaN       NaN
# 7                7       vdisc_testcase_7       NaN       NaN
# 8                8       vdisc_testcase_8       NaN       NaN
# 9                9       vdisc_testcase_9       NaN       NaN
# 10              10      vdisc_testcase_10       NaN       NaN
# 11              11      vdisc_testcase_11       NaN       NaN
# 12              12      vdisc_testcase_12       NaN       NaN
# 13              13      vdisc_testcase_13       NaN       NaN
# ...

# %%
datat = pd.read_csv('./vdisc_validate.csv.gz')

# %%
datat
# Out:
#         Unnamed: 0            testcase_ID  flaw_loc  filename  \
# 0                0       vdisc_testcase_0       NaN       NaN
# 1                1       vdisc_testcase_1       NaN       NaN
# 2                2       vdisc_testcase_2       NaN       NaN
# 3                3       vdisc_testcase_3       NaN       NaN
# 4                4       vdisc_testcase_4       NaN       NaN
# 5                5       vdisc_testcase_5       NaN       NaN
# 6                6       vdisc_testcase_6       NaN       NaN
# 7                7       vdisc_testcase_7       NaN       NaN
# 8                8       vdisc_testcase_8       NaN       NaN
# 9                9       vdisc_testcase_9       NaN       NaN
# 10              10      vdisc_testcase_10       NaN       NaN
# 11              11      vdisc_testcase_11       NaN       NaN
# 12              12      vdisc_testcase_12       NaN       NaN
# 13              13      vdisc_testcase_13       NaN       NaN
# ...

# %%
datat = pd.read_csv('./vdisc_test_all.csv')

# %%
datat
# Out:
#         Unnamed: 0            testcase_ID  \
# 0                0       vdisc_testcase_0
# 1                1       vdisc_testcase_1
# 2                2       vdisc_testcase_2
# 3                3       vdisc_testcase_3
# 4                4       vdisc_testcase_4
# 5                5       vdisc_testcase_5
# 6                6       vdisc_testcase_6
# 7                7       vdisc_testcase_7
# 8                8       vdisc_testcase_8
# 9                9       vdisc_testcase_9
# 10              10      vdisc_testcase_10
# 11              11      vdisc_testcase_11
# 12              12      vdisc_testcase_12
# 13              13      vdisc_testcase_13
# 14              14      vdisc_testcase_14
# 15              15      vdisc_testcase_15
# 16              16      vdisc_testcase_16
# 17              17      vdisc_testcase_17
# 18              18      vdisc_testcase_18
# 19              19      vdisc_testcase_19
# 20              20      vdisc_testcase_20
# ...

# %%
datasmall = pd.read_csv('./vdisc_train_buffer_over_data_small.csv.gz')

# %%
datasmall
# Out:
#        Unnamed: 0  testcase_ID  flaw_loc filename  \
# 0              80            0       NaN   test.c
# 1             112            1       NaN   test.c
# 2             148            2       NaN   test.c
# 3             155            3       NaN   test.c
# 4             235            4       NaN   test.c
# 5             358            5       NaN   test.c
# 6             521            6       NaN   test.c
# 7             548            7       NaN   test.c
# 8             776            8       NaN   test.c
# 9             784            9       NaN   test.c
# 10            788           10       NaN   test.c
# 11            861           11       NaN   test.c
# 12           1114           12       NaN   test.c
# 13           1150           13       NaN   test.c
# 14           1155           14       NaN   test.c
# 15           1372           15       NaN   test.c
# 16           1443           16       NaN   test.c
# 17           1454           17       NaN   test.c
# ...

# %%
bug_label = list(map(sum,np.array(pd.DataFrame(datasmall["buffer"]))))

# %%
print("It contains %s bug examples." % sum(np.array(bug_label)>0))
# Out:
# It contains 14364 bug examples.
