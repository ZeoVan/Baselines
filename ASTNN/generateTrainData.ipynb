# %%
from pipeline import *
# Out:
# /usr/local/lib/python3.6/dist-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %%
ppl = Pipeline('3:1:1', './')
ppl.run()

# %%
unpickled_df = pd.read_pickle("ast.pkl")

# %%
unpickled_df["code"]

# %%
unpickled_df2 = pd.read_pickle("ast.pkl")
unpickled_df2

# %%
unpickled_df2 = pd.read_pickle("_train.pkl")
unpickled_df2

# %%
unpickled_df2 = pd.read_pickle("train/train_.pkl")
unpickled_df2

# %%
from pipeline import *

# %%
source = Pipeline.parse_source(output_file='ast.pkl',option='existing')

# %%
ppl = Pipeline('3:1:1', './')
source = ppl.parse_source(output_file='ast.pkl',option='existing')

# %%
source

# %%
s = pd.read_csv('vdisc_train_buffer_over_data_small.csv.gz')

# %%
x = []
x.append(s.groupby(['testcase_ID']).apply(
            process_for_subtree,
            axis='columns',
            meta=('processed_for_subtree', 'unicode'),
            ))

# %%
x

# %%
s

# %%
labels = s.copy()
del labels['Unnamed: 0']
labels.drop_duplicates(subset ='testcase_ID', keep = False, inplace = True)
labels

# %%
s1 = pd.read_csv('vdisc_train_buffer_over_data_small.csv.gz')
s1

# %%
s['data'] = (s.groupby(['testcase_ID']).apply(
            process_for_subtree,
            axis='columns',
            meta=('processed_for_subtree', 'unicode'),
            ))

# %%
s

# %%
s.to_pickle('sast.pkl')

# %%
ppl = Pipeline('3:1:1', './')
source = ppl.parse_source(output_file='ast.pkl',option='existing')

# %%
source

# %%
ppl2 = Pipeline('3:1:1', './')
source2 = ppl.parse_source(output_file='ast.pkl',option='existing')

# %%
ppl = Pipeline('3:1:1', './')
source = ppl.parse_source(output_file='ast.pkl',option='existing')

# %%
e = pd.read_csv('vdisc_train_buffer_over_data_small.csv.gz')
e

# %%
unpickled_df11 = pd.read_pickle("train/blocks.pkl")

# %%
unpickled_df11
# Out:
#        Unnamed: 0  testcase_ID  flaw_loc filename  \
# 19094        4792        19094       NaN   test.c
# 3134       212912         3134       NaN   test.c
# 2701       184597         2701       NaN   test.c
# 18719        4413        18719       NaN   test.c
# 20834        6560        20834       NaN   test.c
# 16225        1885        16225       NaN   test.c
# 15717        1368        15717       NaN   test.c
# 28480       14323        28480       NaN   test.c
# 8819       594568         8819       NaN   test.c
# 3243       219407         3243       NaN   test.c
# 6036       405138         6036       NaN   test.c
# 25532       11335        25532       NaN   test.c
# 21156        6889        21156       NaN   test.c
# 12162      819997        12162       NaN   test.c
# 19835        5543        19835       NaN   test.c
# 7321       492711         7321       NaN   test.c
# 27427       13261        27427       NaN   test.c
# 19039        4736        19039       NaN   test.c
# ...
